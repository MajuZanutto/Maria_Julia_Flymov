# %%
from typing import Tuple, List, Dict

import pandas as pd
import folium
import numpy as np
   

pd.set_option('display.precision', 2)


df_sites = pd.DataFrame(
    [['hotel',              48.8527, 2.3542],
     ['Sacre Coeur',        48.8867, 2.3431],
     ['Louvre',             48.8607, 2.3376],
     ['Montmartre',         48.8872, 2.3388],
     ['Port de Suffren',    48.8577, 2.2902],
     ['Arc de Triomphe',    48.8739, 2.2950],
     ['Av. Champs Élysées', 48.8710, 2.3036],
     ['Notre Dame',         48.8531, 2.3498],
     ['Tour Eiffel',        48.8585, 2.2945]],
    columns=pd.Index(['site', 'latitude', 'longitude'], name='paris')
)

df_sites
# Out:
# paris                site  latitude  longitude
# 0                   hotel     48.85       2.35
# 1             Sacre Coeur     48.89       2.34
# 2                  Louvre     48.86       2.34
# 3              Montmartre     48.89       2.34
# 4         Port de Suffren     48.86       2.29
# 5         Arc de Triomphe     48.87       2.29
# 6      Av. Champs Élysées     48.87       2.30
# 7              Notre Dame     48.85       2.35
# 8             Tour Eiffel     48.86       2.29

# %%
avg_location = df_sites[['latitude', 'longitude']].mean()
map_paris = folium.Map(location=avg_location, zoom_start=13)

for site in df_sites.itertuples():
    marker = folium.Marker(location=(site.latitude, site.longitude),
                           tooltip=site.site)
    marker.add_to(map_paris)

map_paris

df_route = df_sites.copy()
df_route.index.name = 'visit_order'

df_route

df_route_segments = df_route.join(
    df_route.shift(-1),  # map each stop to its next stop
    rsuffix='_next'
).dropna()  # last stop has no "next one", so drop it

df_route_segments

map_paris = folium.Map(location=avg_location, zoom_start=13)

for stop in df_route_segments.itertuples():
    # marker for current stop
    marker = folium.Marker(location=(stop.latitude, stop.longitude),
                           tooltip=stop.site)
    # line for the route segment connecting current to next stop
    line = folium.PolyLine(
        locations=[(stop.latitude, stop.longitude), 
                   (stop.latitude_next, stop.longitude_next)],
        tooltip=f"{stop.site} to {stop.site_next}",
    )
    # add elements to the map
    marker.add_to(map_paris)
    line.add_to(map_paris)

# maker for last stop wasn't added in for loop, so adding it now 
folium.Marker(location=(stop.latitude_next, stop.longitude_next),
              tooltip=stop.site_next).add_to(map_paris);

map_paris

map_paris = folium.Map(location=avg_location, zoom_start=13)

for stop in df_route_segments.itertuples():
    initial_stop = stop.Index == 0
    # icon for current stop
    icon = folium.Icon(icon='home' if initial_stop else 'info-sign', 
                       color='cadetblue' if initial_stop else 'red')
    # marker for current stop
    marker = folium.Marker(location=(stop.latitude, stop.longitude),
                           icon=icon, tooltip=stop.site)
    # line for the route segment connecting current to next stop
    line = folium.PolyLine(
        locations=[(stop.latitude, stop.longitude), 
                   (stop.latitude_next, stop.longitude_next)],
        tooltip=f"{stop.site} to {stop.site_next}",
    )
    # add elements to the map
    marker.add_to(map_paris)
    line.add_to(map_paris)

# When for loop ends, the stop variable has the second-to-last 
# stop in the route, so the marker for the last stop is missing 
# We add it now using the "next" columns of the last row
folium.Marker(
    location=(stop.latitude_next, stop.longitude_next),
    tooltip=stop.site_next, 
    icon = folium.Icon(icon='info-sign', color='red')
).add_to(map_paris);

from geoutils import GeoAnalyzer

from geopy.distance import geodesic

_Location = Tuple[float, float]


def ellipsoidal_distance(point1: _Location, point2: _Location) -> float:
    """Calculate ellipsoidal distance (in meters) between point1 and 
    point2 where each point is represented as a tuple (lat, lon)"""
    return geodesic(point1, point2).meters

df_route_segments['distance_seg'] = df_route_segments.apply(
    lambda stop: ellipsoidal_distance(
        (stop.latitude, stop.longitude), 
        (stop.latitude_next, stop.longitude_next)), 
    axis=1
)

df_route_segments
# Out:
# C:\Users\flymo\AppData\Roaming\Python\Python39\site-packages\folium\utilities.py:86: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   coords = (location[0], location[1])
# C:\Users\flymo\AppData\Roaming\Python\Python39\site-packages\folium\utilities.py:86: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   coords = (location[0], location[1])
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[9], line 74
#      65 # When for loop ends, the stop variable has the second-to-last
#      66 # stop in the route, so the marker for the last stop is missing
#      67 # We add it now using the "next" columns of the last row
#      68 folium.Marker(
#      69     location=(stop.latitude_next, stop.longitude_next),
#      70     tooltip=stop.site_next,
#      71     icon = folium.Icon(icon='info-sign', color='red')
#      72 ).add_to(map_paris);
# ---> 74 from geoutils import GeoAnalyzer
#      76 from geopy.distance import geodesic
#      78 _Location = Tuple[float, float]
#
# File ~\AppData\Roaming\Python\Python39\site-packages\geoutils\__init__.py:5
#       1 """
#       2 GeoUtils is a Python package for the analysis of geospatial data.
#       3 """
# ----> 5 from geoutils import examples, projtools, raster, vector  # noqa
#       6 from geoutils._config import config  # noqa
#       7 from geoutils.raster import Mask, Raster, SatelliteImage  # noqa
#
# File ~\AppData\Roaming\Python\Python39\site-packages\geoutils\raster\__init__.py:1
# ----> 1 from geoutils.raster.raster import Raster, RasterType, Mask, handled_array_funcs  # noqa isort:skip
#       2 from geoutils.raster.array import *  # noqa
#       3 from geoutils.raster.multiraster import *  # noqa
#
# File ~\AppData\Roaming\Python\Python39\site-packages\geoutils\raster\raster.py:23
#      21 import rasterio.warp
#      22 import rasterio.windows
# ---> 23 import rioxarray
#      24 import xarray as xr
#      25 from affine import Affine
#
# File ~\AppData\Roaming\Python\Python39\site-packages\rioxarray\__init__.py:5
#       2 __author__ = """rioxarray Contributors"""
#       3 import importlib.metadata
# ----> 5 import rioxarray.raster_array  # noqa
#       6 import rioxarray.raster_dataset  # noqa
#       7 from rioxarray._io import open_rasterio
#
# File ~\AppData\Roaming\Python\Python39\site-packages\rioxarray\raster_array.py:30
#      27 from xarray.backends.file_manager import FileManager
#      28 from xarray.core.dtypes import get_fill_value
# ---> 30 from rioxarray._io import FILL_VALUE_NAMES, UNWANTED_RIO_ATTRS
#      31 from rioxarray.crs import crs_from_user_input
#      32 from rioxarray.exceptions import (
#      33     MissingCRS,
#      34     NoDataInBounds,
#      35     OneDimensionalRaster,
#      36     RioXarrayError,
#      37 )
#
# File ~\AppData\Roaming\Python\Python39\site-packages\rioxarray\_io.py:539
#     532         parsed_tags[key] = value
#     533     return parsed_tags
#     536 NETCDF_DTYPE_MAP = {
#     537     0: object,  # NC_NAT
#     538     1: numpy.byte,  # NC_BYTE
# --> 539     2: numpy.char,  # NC_CHAR
#     540     3: numpy.short,  # NC_SHORT
#     541     4: numpy.int_,  # NC_INT, NC_LONG
#     542     5: float,  # NC_FLOAT
#     543     6: numpy.double,  # NC_DOUBLE
#     544     7: numpy.ubyte,  # NC_UBYTE
#     545     8: numpy.ushort,  # NC_USHORT
#     546     9: numpy.uint,  # NC_UINT
#     547     10: numpy.int64,  # NC_INT64
#     548     11: numpy.uint64,  # NC_UINT64
#     549     12: object,  # NC_STRING
#     550 }
#     553 def _load_netcdf_attrs(tags: dict, data_array: DataArray) -> None:
#     554     """
#     555     Loads the netCDF attributes into the data array
#     556
#     557     Attributes stored in this format:
#     558     - variable_name#attr_name: attr_value
#     559     """
#
# File ~\AppData\Roaming\Python\Python39\site-packages\numpy\__init__.py:397, in __getattr__(attr)
#     394         raise AssertionError()
#     395 except AssertionError:
#     396     msg = ("The current Numpy installation ({!r}) fails to "
# --> 397            "pass simple sanity checks. This can be caused for example "
#     398            "by incorrect BLAS library being linked in, or by mixing "
#     399            "package managers (pip, conda, apt, ...). Search closed "
#     400            "numpy issues for similar problems.")
#     401     raise RuntimeError(msg.format(__file__)) from None
#
# ModuleNotFoundError: No module named 'numpy.char'
